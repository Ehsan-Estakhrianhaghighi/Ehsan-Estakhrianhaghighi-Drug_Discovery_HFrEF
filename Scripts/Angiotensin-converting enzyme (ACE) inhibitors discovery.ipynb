# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import PandasTools
import pandas as pd
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %%
# Load the data, from SMILES strings
t1 = "O=C(OCC)[C@@H](N[C@@H]2C(=O)N(c1ccccc1CC2)CC(=O)O)CCc3ccccc3"
t1 = Chem.MolFromSmiles(t1)

t2 = "O=C(O)[C@H]1N(C(=O)[C@H](C)CS)CCC1"
t2 = Chem.MolFromSmiles(t2)

t3 = "O=C(O)[C@H]2N(C(=O)[C@@H](N[C@H](C(=O)OCC)CCc1ccccc1)C)CCC2"
t3 = Chem.MolFromSmiles(t3)

target_drugs = [t1, t2, t3]

# %%
from rdkit.Chem import Draw
Draw.MolsToGridImage([t1, t2, t3])

# %%
# %run clustering_with_molecular_fingerprints.ipynb
# Out:
# Failed to patch pandas - unable to change molecule rendering
# 80
# 69
# 58
# 33
# 52

# %%
# Cluster the fingerprints
clusters = ClusterFps(fps,cutoff=0.5)
# Let's see how many clusters we have
len(clusters)
# Out:
# 200

# %%
type(clusters[0][0])
# Out:
# int

# %%
# find the cluster that each target drug belongs to# first turn the target drugs into ids
for cluster in clusters:
    for molecule in cluster:
        moleule =
target_clusters = [find_cluster(molecule=t, clusters=clusters) for t in target_drugs]
target_clusters
# Out:
# [None, None, None]
